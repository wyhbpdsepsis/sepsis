# %%
import pandas as pd
df = pd.read_csv('C:/Users/hmoye/Desktop/BPD8-23_1.csv')
df
# Out:
#      sex    GW     BWt  Csec  S_M  stay_in_hospital Invasive_time  \
# 0      1  28.0     NaN     2    1             150.0           116
# 1      1  26.0     NaN     2    1              80.0            30
# 2      1  27.0     NaN     2    2              53.0            53
# 3      2  26.0     NaN     1    2              73.0             4
# 4      2  26.0     NaN     1    2              90.0             8
# ..   ...   ...     ...   ...  ...               ...           ...
# 301    2  32.0  1930.0     1    1              41.0             6
# 302    1  34.0  2300.0     2    1              44.0            18
# 303    1  35.0  2410.0     2    1              45.0            26
# 304    1  31.0  2450.0     1    1             136.0            10
# 305    1   NaN  3680.0     1    1              91.0            30
#
#     nonInvasive_time  oxgen_time  CRIBII评分  ...  maternal_age  ROP early_PH  \
# 0                 34         0.0       NaN  ...            29  NaN      1.0
# 1                  8         3.0       NaN  ...            37  0.0      1.0
# 2                  0         0.0       NaN  ...            27  NaN      1.0
# 3                 42         1.0       NaN  ...            33  0.0      2.0
# 4                 31        12.0       NaN  ...            33  0.0      2.0
# ..               ...         ...       ...  ...           ...  ...      ...
# 301                7        18.0       0.0  ...            36  0.0      1.0
# 302                9         6.0       0.0  ...            26  0.0      1.0
# 303                2         4.0       0.0  ...            28  0.0      1.0
# 304                7        17.0       0.0  ...           NaN  2.0      1.0
# 305               13         8.0       0.0  ...           NaN  NaN      1.0
#
#      PDA  NEC  WMI  BPD  BPD_HP  IVH chorioamnionitis
# 0    1.0    0    2    3     1.0  1.0                2
# 1    1.0    0    2    3     1.0  1.0                2
# 2    1.0    0    2    3     NaN  1.0                2
# 3    1.0    0    2    2     1.0  2.0                2
# 4    1.0    0    2    3     1.0  1.0                2
# ..   ...  ...  ...  ...     ...  ...              ...
# 301  1.0    0    2    1     1.0  2.0                2
# 302  3.0    0    2    1     1.0  2.0                2
# 303  1.0    0    2    3     1.0  2.0                2
# 304  1.0    0    2    2     1.0  1.0                2
# 305  3.0    0    2    3     1.0  NaN                2
#
# [306 rows x 30 columns]

# %%
import matplotlib
from matplotlib import pyplot
import matplotlib.pyplot as plt
import missingno as msno
# %matplotlib inline
msno.matrix(df)
# Out:
# <AxesSubplot:>
# D:\ProgramData\Anaconda3\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 35780 (\N{CJK UNIFIED IDEOGRAPH-8BC4}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# D:\ProgramData\Anaconda3\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 20998 (\N{CJK UNIFIED IDEOGRAPH-5206}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
import matplotlib.pyplot as plt
import missingno as msno
msno.matrix(df, figsize=(12, 6))
# 显示图表
plt.show() 
# 保存图表为PDF
plt.savefig('missing_values7.pdf')

# %%
path ='C:/Users/hmoye/Desktop/'
fig = plt.figure(figsize=(16,8))
msno.matrix(df)
fig = plt.gcf()
plt.show()
fig.savefig(path+'missingno7.svg',format='svg',dip=300)
# Out:
# C:\Users\hmoye\AppData\Local\Temp\ipykernel_13628\2560607204.py:6: MatplotlibDeprecationWarning: savefig() got unexpected keyword argument "dip" which is no longer supported as of 3.3 and will become an error in 3.6
#   fig.savefig(path+'missingno7.svg',format='svg',dip=300)
# C:\Users\hmoye\AppData\Local\Temp\ipykernel_13628\2560607204.py:6: UserWarning: Glyph 35780 (\N{CJK UNIFIED IDEOGRAPH-8BC4}) missing from current font.
#   fig.savefig(path+'missingno7.svg',format='svg',dip=300)
# C:\Users\hmoye\AppData\Local\Temp\ipykernel_13628\2560607204.py:6: UserWarning: Glyph 20998 (\N{CJK UNIFIED IDEOGRAPH-5206}) missing from current font.
#   fig.savefig(path+'missingno7.svg',format='svg',dip=300)

# %%
msno.bar(df)
fig = plt.gcf()
# 显示图形
plt.show() 
# 保存图形为PDF
plt.savefig('missing_values_bar1.pdf')

# %%
msno.heatmap(df)
# Out:
# D:\ProgramData\Anaconda3\lib\site-packages\seaborn\utils.py:95: UserWarning: Glyph 35780 (\N{CJK UNIFIED IDEOGRAPH-8BC4}) missing from current font.
#   fig.canvas.draw()
# D:\ProgramData\Anaconda3\lib\site-packages\seaborn\utils.py:95: UserWarning: Glyph 20998 (\N{CJK UNIFIED IDEOGRAPH-5206}) missing from current font.
#   fig.canvas.draw()
# D:\ProgramData\Anaconda3\lib\site-packages\seaborn\utils.py:660: UserWarning: Glyph 35780 (\N{CJK UNIFIED IDEOGRAPH-8BC4}) missing from current font.
#   bboxes = [l.get_window_extent() for l in labels]
# D:\ProgramData\Anaconda3\lib\site-packages\seaborn\utils.py:660: UserWarning: Glyph 20998 (\N{CJK UNIFIED IDEOGRAPH-5206}) missing from current font.
#   bboxes = [l.get_window_extent() for l in labels]
# <AxesSubplot:>
# D:\ProgramData\Anaconda3\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 35780 (\N{CJK UNIFIED IDEOGRAPH-8BC4}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# D:\ProgramData\Anaconda3\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 20998 (\N{CJK UNIFIED IDEOGRAPH-5206}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
