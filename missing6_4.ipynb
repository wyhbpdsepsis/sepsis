# %%
import pandas as pd
import platform
import matplotlib.pyplot as plt
plt.rcParams['font.sans-serif'] = ['Arial Unicode MS']
df = pd.read_csv('/Users/hmoye/Desktop/sepsis-main-2/BPD8-23_1.csv')
df
# Out:
#      sex    GW     BWt  Csec  S_M  stay_in_hospital Invasive_time  \
# 0      1  28.0     NaN     2    1             150.0           116
# 1      1  26.0     NaN     2    1              80.0            30
# 2      1  27.0     NaN     2    2              53.0            53
# 3      2  26.0     NaN     1    2              73.0             4
# 4      2  26.0     NaN     1    2              90.0             8
# ..   ...   ...     ...   ...  ...               ...           ...
# 301    2  32.0  1930.0     1    1              41.0             6
# 302    1  34.0  2300.0     2    1              44.0            18
# 303    1  35.0  2410.0     2    1              45.0            26
# 304    1  31.0  2450.0     1    1             136.0            10
# 305    1   NaN  3680.0     1    1              91.0            30
#
#     nonInvasive_time  oxgen_time  CRIBII评分  ...  maternal_age  ROP early_PH  \
# 0                 34         0.0       NaN  ...            29  NaN      1.0
# ...

# %%
import matplotlib
from matplotlib import pyplot
import matplotlib.pyplot as plt
import missingno as msno
# %matplotlib inline
msno.matrix(df)
# Out:
# <Axes: >

# %%
import platform
import missingno as msno
msno.matrix(df, figsize=(12, 6))
# 显示图表
plt.show() 
# 保存图表为PDF
plt.savefig('missing_values7.pdf')

# %%
path ='/Users/hmoye/Desktop/'
fig = plt.figure(figsize=(16,8))
msno.matrix(df)
fig = plt.gcf()
plt.show()
fig.savefig(path+'missingno7.svg',format='svg',dpi=300)

# %%
msno.bar(df)
fig = plt.gcf()
# 显示图形
plt.show() 
# 保存图形为PDF
plt.savefig('missing_values_bar1.pdf')

# %%
msno.heatmap(df)
# Out:
# <Axes: >
